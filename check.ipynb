# %% [markdown]
# # STAT163 — Setup check
#
# Verifies your Python and pandas environment before the first practice session.
#
# ## What to do
#
# 1. Run every cell below in order — press `Shift+Enter` while in the cell.
# 2. Every cell must finish without errors.
# 3. Save the notebook, then commit and push (see the README).

# %% [markdown]
# ## Step 1. Introduce yourself
#
# In the cell below, replace `_your name_` with your real name (keep the quotes), then run
# the cell (`Shift+Enter`).

# %%
# replace here
NAME = "Sofiia_Korolova-Kazanska"

# do not change anything below
assert NAME != "_your name_", "Replace the value of NAME with your name"
print(NAME)
# Out:
# Sofiia_Korolova-Kazanska

# %% [markdown]
# ## Step 2. pandas version
#
# Run the cell. It prints the pandas version installed in your environment.

# %%
import pandas as pd

print("pandas:", pd.__version__)
# Out:
# pandas: 3.0.5

# %% [markdown]
# ## Step 3. System information
#
# This records your operating system, CPU architecture and Python version. The output is
# saved in the notebook — useful for diagnostics if anything misbehaves later.

# %%
import platform

print("Python:      ", platform.python_version())
print("OS:          ", platform.system(), platform.release())
print("Architecture:", platform.machine())
print("Platform:    ", platform.platform())
# Out:
# Python:       3.14.5
# OS:           Windows 11
# Architecture: AMD64
# Platform:     Windows-11-10.0.26200-SP0

# %% [markdown]
# ## Step 4. Creating a pandas table
#
# A `DataFrame` is the object we work with for the whole course. After running the cell, a
# small table with your name and system information should appear.

# %%
df = pd.DataFrame({
    "name": [NAME],
    "python": [platform.python_version()],
    "pandas": [pd.__version__],
    "os": [platform.system()],
    "arch": [platform.machine()],
})
df
# Out:
#                        name  python pandas       os   arch
# 0  Sofiia_Korolova-Kazanska  3.14.5  3.0.5  Windows  AMD64

# %% [markdown]
# ## Done
#
# If every cell ran without errors, your environment works.
#
# Save the notebook (`Cmd+S` or `Ctrl+S`), then in the terminal:
#
# ```
# git add check.ipynb
# git commit -m "Setup check"
# git push
# ```
#
# After the push, refresh your repository page on GitHub — a green ✓ next to the commit
# means the automatic check passed.
